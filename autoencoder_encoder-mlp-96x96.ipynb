# %%
from datasets import load_dataset
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras import layers, models, callbacks
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score

tf.config.list_physical_devices('GPU')
print("✅ Entorno limpio y funcionando")
# Out:
# ✅ Entorno limpio y funcionando

# %%
#Se carga el dataset desde HuggingFace
dataset = load_dataset("zguo0525/ArtBench")

#Se obtienen las divisiones
train_ds = dataset["train"]
test_ds = dataset["test"]

#Ejemplo
ej = train_ds[100]
img_array = np.array(ej["image"])
print("Etiqueta:", ej["label"], "| Imagen shape:", img_array.shape)
plt.imshow(img_array)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/721 [00:00<?, ?B/s]
# data/train-00000-of-00004.parquet:   0%|          | 0.00/418M [00:00<?, ?B/s]
# data/train-00001-of-00004.parquet:   0%|          | 0.00/408M [00:00<?, ?B/s]
# data/train-00002-of-00004.parquet:   0%|          | 0.00/385M [00:00<?, ?B/s]
# data/train-00003-of-00004.parquet:   0%|          | 0.00/406M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/323M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Etiqueta: 0 | Imagen shape: (256, 256, 3)

# %%
IMG_SIZE = 96

def preprocess_tf(example):
    #Se realiza la siguiente conversión: PIL -> NumPy -> Tensor
    image = np.array(example["image"])
    image = tf.convert_to_tensor(image)
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE)) #Redimensión
    image = tf.cast(image, tf.float32) / 255.0   # normalización [0,1]
    label = example["label"]
    return {"image": image, "label": label}

#Se aplica una transformación eficiente sin cargar todo a memoria
#Para que colab no explote c:
train_tf = dataset["train"].with_transform(preprocess_tf)
test_tf  = dataset["test"].with_transform(preprocess_tf)

tf_train = train_tf.to_tf_dataset(
    columns="image",
    label_cols="label",
    batch_size=64,
    shuffle=True,
    drop_remainder=True
)

tf_test = test_tf.to_tf_dataset(
    columns="image",
    label_cols="label",
    batch_size=64,
    drop_remainder=True
)

#Se crean los nuevos datasets para Keras
tf_train_ae = train_tf.to_tf_dataset(
    columns="image",
    label_cols=None,
    batch_size=64,
    shuffle=True
).map(lambda x: (x, x))

tf_test_ae = test_tf.to_tf_dataset(
    columns="image",
    label_cols=None,
    batch_size=64
).map(lambda x: (x, x))

# %%
tf.keras.backend.clear_session()
latent_dim = 256
IMG_SIZE = 96

def fast_autoencoder(img_size=64):
    inp = layers.Input((img_size, img_size, 3))

    # -------- ENCODER ----------
    x = layers.Conv2D(16, 3, activation="relu", padding="same")(inp)
    x = layers.MaxPool2D(2)(x)

    x = layers.Conv2D(32, 3, activation="relu", padding="same")(x)
    x = layers.MaxPool2D(2)(x)

    x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
    x = layers.MaxPool2D(2)(x)

    shape_before = tf.keras.backend.int_shape(x)

    x = layers.Flatten()(x)
    latent = layers.Dense(latent_dim)(x)

    # -------- DECODER ----------
    x = layers.Dense(shape_before[1]*shape_before[2]*shape_before[3], activation="relu")(latent)
    x = layers.Reshape((shape_before[1], shape_before[2], shape_before[3]))(x)

    x = layers.UpSampling2D()(x)
    x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)

    x = layers.UpSampling2D()(x)
    x = layers.Conv2D(32, 3, activation="relu", padding="same")(x)

    x = layers.UpSampling2D()(x)
    out = layers.Conv2D(3, 3, activation="sigmoid", padding="same")(x)

    ae = models.Model(inp, out)
    enc = models.Model(inp, latent)
    return ae, enc

autoencoder, encoder = fast_autoencoder(IMG_SIZE)

# %%
import tensorflow as tf
import tensorflow.image as tfi
import keras.backend as K
def ssim_metric(y_true, y_pred):
    # SSIM devuelve valores por imagen, así que promediamos
    return tf.reduce_mean(tfi.ssim(y_true, y_pred, max_val=1.0))


autoencoder.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss="mae",                   # tu loss principal
    metrics=[
        tf.keras.metrics.MeanSquaredError(name="mse"),
        ssim_metric                # métrica personalizada
    ]
)


history = autoencoder.fit(
    tf_train_ae,
    validation_data=tf_test_ae,
    epochs=20,
    verbose=1,
    callbacks=[
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=3
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=6,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 126s 148ms/step - loss: 0.1570 - mse: 0.0415 - ssim_metric: 0.2580 - val_loss: 0.0974 - val_mse: 0.0190 - val_ssim_metric: 0.3253 - learning_rate: 1.0000e-04
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 109s 140ms/step - loss: 0.0943 - mse: 0.0180 - ssim_metric: 0.3355 - val_loss: 0.0882 - val_mse: 0.0161 - val_ssim_metric: 0.3581 - learning_rate: 1.0000e-04
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 108s 139ms/step - loss: 0.0862 - mse: 0.0156 - ssim_metric: 0.3650 - val_loss: 0.0834 - val_mse: 0.0147 - val_ssim_metric: 0.3764 - learning_rate: 1.0000e-04
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 109s 139ms/step - loss: 0.0817 - mse: 0.0144 - ssim_metric: 0.3817 - val_loss: 0.0802 - val_mse: 0.0138 - val_ssim_metric: 0.3894 - learning_rate: 1.0000e-04
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 109s 139ms/step - loss: 0.0789 - mse: 0.0136 - ssim_metric: 0.3934 - val_loss: 0.0775 - val_mse: 0.0132 - val_ssim_metric: 0.3996 - learning_rate: 1.0000e-04
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 109s 140ms/step - loss: 0.0767 - mse: 0.0130 - ssim_metric: 0.4043 - val_loss: 0.0761 - val_mse: 0.0128 - val_ssim_metric: 0.4078 - learning_rate: 1.0000e-04
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 109s 140ms/step - loss: 0.0755 - mse: 0.0127 - ssim_metric: 0.4104 - val_loss: 0.0752 - val_mse: 0.0126 - val_ssim_metric: 0.4146 - learning_rate: 1.0000e-04
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 109s 140ms/step - loss: 0.0744 - mse: 0.0125 - ssim_metric: 0.4161 - val_loss: 0.0741 - val_mse: 0.0124 - val_ssim_metric: 0.4209 - learning_rate: 1.0000e-04
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 109s 139ms/step - loss: 0.0731 - mse: 0.0121 - ssim_metric: 0.4231 - val_loss: 0.0731 - val_mse: 0.0120 - val_ssim_metric: 0.4246 - learning_rate: 1.0000e-04
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 108s 138ms/step - loss: 0.0724 - mse: 0.0119 - ssim_metric: 0.4274 - val_loss: 0.0727 - val_mse: 0.0120 - val_ssim_metric: 0.4301 - learning_rate: 1.0000e-04
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 108s 138ms/step - loss: 0.0713 - mse: 0.0116 - ssim_metric: 0.4341 - val_loss: 0.0716 - val_mse: 0.0117 - val_ssim_metric: 0.4331 - learning_rate: 1.0000e-04
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 113s 145ms/step - loss: 0.0710 - mse: 0.0116 - ssim_metric: 0.4355 - val_loss: 0.0711 - val_mse: 0.0115 - val_ssim_metric: 0.4357 - learning_rate: 1.0000e-04
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 111s 142ms/step - loss: 0.0702 - mse: 0.0114 - ssim_metric: 0.4395 - val_loss: 0.0709 - val_mse: 0.0116 - val_ssim_metric: 0.4394 - learning_rate: 1.0000e-04
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 110s 141ms/step - loss: 0.0699 - mse: 0.0113 - ssim_metric: 0.4412 - val_loss: 0.0702 - val_mse: 0.0114 - val_ssim_metric: 0.4422 - learning_rate: 1.0000e-04
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 110s 141ms/step - loss: 0.0695 - mse: 0.0112 - ssim_metric: 0.4442 - val_loss: 0.0697 - val_mse: 0.0113 - val_ssim_metric: 0.4440 - learning_rate: 1.0000e-04
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 112s 143ms/step - loss: 0.0688 - mse: 0.0111 - ssim_metric: 0.4480 - val_loss: 0.0693 - val_mse: 0.0111 - val_ssim_metric: 0.4463 - learning_rate: 1.0000e-04
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 113s 144ms/step - loss: 0.0685 - mse: 0.0110 - ssim_metric: 0.4492 - val_loss: 0.0691 - val_mse: 0.0111 - val_ssim_metric: 0.4484 - learning_rate: 1.0000e-04
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 112s 143ms/step - loss: 0.0684 - mse: 0.0110 - ssim_metric: 0.4520 - val_loss: 0.0692 - val_mse: 0.0112 - val_ssim_metric: 0.4505 - learning_rate: 1.0000e-04
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 110s 140ms/step - loss: 0.0679 - mse: 0.0109 - ssim_metric: 0.4539 - val_loss: 0.0695 - val_mse: 0.0110 - val_ssim_metric: 0.4508 - learning_rate: 1.0000e-04
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 110s 140ms/step - loss: 0.0676 - mse: 0.0108 - ssim_metric: 0.4560 - val_loss: 0.0684 - val_mse: 0.0110 - val_ssim_metric: 0.4539 - learning_rate: 1.0000e-04

# %%
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 96, 96, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 48, 48, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,359,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9216)           │     2,368,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 48, 48, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 96, 96, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 96, 96, 3)      │           867 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,423,723 (55.02 MB)
#  Trainable params: 4,807,907 (18.34 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 9,615,816 (36.68 MB)

# %%
encoder_fixed = tf.keras.Model(
    inputs=autoencoder.input,
    outputs=autoencoder.layers[9].output   # capa Dense (256)
)

for batch, _ in tf_test_ae.take(1):
    originals = batch.numpy()
    recons = autoencoder.predict(originals[:8])
    embeds = encoder_fixed.predict(originals[:8])

N = 8
latent_dim = embeds.shape[1]
side = int(np.sqrt(latent_dim))   # 16 si latent_dim = 256

plt.figure(figsize=(18, 8))

for i in range(N):
    # Original
    plt.subplot(3, N, i+1)
    plt.imshow(originals[i])
    plt.title("Original")
    plt.axis("off")

    # Embedding como imagen
    emb_img = embeds[i].reshape(side, side)
    plt.subplot(3, N, i+1+N)
    plt.imshow(emb_img, cmap='gray')
    plt.title("Embedding")
    plt.axis("off")

    # Reconstrucción
    plt.subplot(3, N, i+1+2*N)
    plt.imshow(recons[i])
    plt.title("Reconstruida")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step

# %%
import numpy as np

def extract_embeddings(encoder, tf_dataset):
    embeddings = []
    labels = []

    for batch_imgs, batch_labels in tf_dataset:
        # Obtener embeddings
        z = encoder.predict(batch_imgs, verbose=0)
        embeddings.append(z)
        labels.append(batch_labels.numpy())

    embeddings = np.concatenate(embeddings, axis=0)
    labels = np.concatenate(labels, axis=0)
    return embeddings, labels

# %%
raw_train = dataset["train"]
raw_test  = dataset["test"]

tf_train = raw_train.to_tf_dataset(
    columns="image",
    label_cols="label",
    batch_size=64,
    shuffle=True,
    drop_remainder=True
)

tf_test = raw_test.to_tf_dataset(
    columns="image",
    label_cols="label",
    batch_size=64,
    drop_remainder=True
)

def preprocess_tf(image, label):
    image = tf.image.resize(image, (96, 96))
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

tf_train = tf_train.map(preprocess_tf)
tf_test  = tf_test.map(preprocess_tf)

def filter_empty(image, label):
    return tf.shape(image)[0] > 0

tf_train = tf_train.filter(filter_empty)
tf_test  = tf_test.filter(filter_empty)
tf_train = tf_train.prefetch(2)
tf_test  = tf_test.prefetch(2)

X_train_emb, y_train = extract_embeddings(encoder, tf_train)
X_test_emb,  y_test  = extract_embeddings(encoder, tf_test)

# %%
X_train_emb.shape, X_test_emb.shape
# Out:
# ((49984, 256), (9984, 256))

# %%
from tensorflow.keras import models, layers, callbacks

mlp = models.Sequential([
    layers.Input(shape=(X_train_emb.shape[1],)),
    layers.Dense(256, activation='relu'),     # un poco más de capacidad
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(64 , activation='relu'),
    layers.Dense(len(np.unique(y_train)), activation='softmax')
])

mlp.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)


early_stop = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,           # si quieres que aprenda más antes de cortar
    restore_best_weights=True
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6
)

checkpoint = callbacks.ModelCheckpoint(
    "best_mlp_model.keras",
    monitor="val_loss",
    save_best_only=True
)

history = mlp.fit(
    X_train_emb, y_train,
    epochs=100,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stop, reduce_lr, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.2070 - loss: 2.1668 - val_accuracy: 0.2899 - val_loss: 1.9913 - learning_rate: 0.0010
# Epoch 2/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2753 - loss: 1.9989 - val_accuracy: 0.3077 - val_loss: 1.9327 - learning_rate: 0.0010
# Epoch 3/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2964 - loss: 1.9492 - val_accuracy: 0.3197 - val_loss: 1.8986 - learning_rate: 0.0010
# Epoch 4/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3159 - loss: 1.9075 - val_accuracy: 0.3236 - val_loss: 1.8816 - learning_rate: 0.0010
# Epoch 5/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3252 - loss: 1.8794 - val_accuracy: 0.3354 - val_loss: 1.8637 - learning_rate: 0.0010
# Epoch 6/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3359 - loss: 1.8486 - val_accuracy: 0.3280 - val_loss: 1.8576 - learning_rate: 0.0010
# Epoch 7/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3416 - loss: 1.8322 - val_accuracy: 0.3348 - val_loss: 1.8473 - learning_rate: 0.0010
# Epoch 8/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3500 - loss: 1.8134 - val_accuracy: 0.3430 - val_loss: 1.8362 - learning_rate: 0.0010
# Epoch 9/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3528 - loss: 1.7969 - val_accuracy: 0.3402 - val_loss: 1.8337 - learning_rate: 0.0010
# Epoch 10/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3536 - loss: 1.7928 - val_accuracy: 0.3365 - val_loss: 1.8360 - learning_rate: 0.0010
# Epoch 11/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3640 - loss: 1.7721 - val_accuracy: 0.3461 - val_loss: 1.8293 - learning_rate: 0.0010
# Epoch 12/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3654 - loss: 1.7641 - val_accuracy: 0.3434 - val_loss: 1.8297 - learning_rate: 0.0010
# Epoch 13/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3698 - loss: 1.7451 - val_accuracy: 0.3444 - val_loss: 1.8231 - learning_rate: 0.0010
# Epoch 14/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3682 - loss: 1.7406 - val_accuracy: 0.3467 - val_loss: 1.8226 - learning_rate: 0.0010
# Epoch 15/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3732 - loss: 1.7382 - val_accuracy: 0.3492 - val_loss: 1.8232 - learning_rate: 0.0010
# Epoch 16/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3791 - loss: 1.7144 - val_accuracy: 0.3469 - val_loss: 1.8232 - learning_rate: 0.0010
# Epoch 17/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3837 - loss: 1.7125 - val_accuracy: 0.3398 - val_loss: 1.8254 - learning_rate: 0.0010
# Epoch 18/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3857 - loss: 1.6993 - val_accuracy: 0.3472 - val_loss: 1.8173 - learning_rate: 0.0010
# Epoch 19/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3865 - loss: 1.6926 - val_accuracy: 0.3438 - val_loss: 1.8190 - learning_rate: 0.0010
# Epoch 20/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3935 - loss: 1.6811 - val_accuracy: 0.3448 - val_loss: 1.8247 - learning_rate: 0.0010
# Epoch 21/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3929 - loss: 1.6784 - val_accuracy: 0.3447 - val_loss: 1.8279 - learning_rate: 0.0010
# Epoch 22/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3930 - loss: 1.6781 - val_accuracy: 0.3414 - val_loss: 1.8307 - learning_rate: 0.0010
# Epoch 23/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3979 - loss: 1.6672 - val_accuracy: 0.3416 - val_loss: 1.8248 - learning_rate: 0.0010
# Epoch 24/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4079 - loss: 1.6402 - val_accuracy: 0.3473 - val_loss: 1.8172 - learning_rate: 5.0000e-04
# Epoch 25/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4124 - loss: 1.6198 - val_accuracy: 0.3482 - val_loss: 1.8212 - learning_rate: 5.0000e-04
# Epoch 26/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4180 - loss: 1.6113 - val_accuracy: 0.3526 - val_loss: 1.8215 - learning_rate: 5.0000e-04
# Epoch 27/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4186 - loss: 1.6100 - val_accuracy: 0.3526 - val_loss: 1.8268 - learning_rate: 5.0000e-04
# Epoch 28/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4214 - loss: 1.5988 - val_accuracy: 0.3506 - val_loss: 1.8280 - learning_rate: 5.0000e-04
# Epoch 29/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4221 - loss: 1.6033 - val_accuracy: 0.3506 - val_loss: 1.8267 - learning_rate: 5.0000e-04
# Epoch 30/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4227 - loss: 1.5888 - val_accuracy: 0.3496 - val_loss: 1.8291 - learning_rate: 2.5000e-04
# Epoch 31/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4263 - loss: 1.5823 - val_accuracy: 0.3468 - val_loss: 1.8303 - learning_rate: 2.5000e-04
# Epoch 32/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4372 - loss: 1.5600 - val_accuracy: 0.3484 - val_loss: 1.8368 - learning_rate: 2.5000e-04
# Epoch 33/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4287 - loss: 1.5646 - val_accuracy: 0.3466 - val_loss: 1.8401 - learning_rate: 2.5000e-04
# Epoch 34/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4315 - loss: 1.5609 - val_accuracy: 0.3503 - val_loss: 1.8375 - learning_rate: 2.5000e-04

# %%
class_names = dataset["train"].features["label"].names
print(class_names)
# Out:
# ['expressionism', 'art_nouveau', 'renaissance', 'ukiyo_e', 'realism', 'romanticism', 'surrealism', 'impressionism', 'baroque', 'post_impressionism']

# %%
import numpy as np

# Predicciones del modelo
y_pred_probs = mlp.predict(X_test_emb)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
from sklearn.metrics import confusion_matrix

print(classification_report(y_test, y_pred, target_names=class_names, digits=3))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=class_names).plot(xticks_rotation=45, cmap="Blues")
# Out:
#                     precision    recall  f1-score   support
#
#      expressionism      0.220     0.193     0.206      1000
#        art_nouveau      0.354     0.384     0.368      1000
#        renaissance      0.316     0.387     0.348      1000
#            ukiyo_e      0.630     0.775     0.695      1000
#            realism      0.243     0.188     0.212      1000
#        romanticism      0.326     0.200     0.248      1000
#         surrealism      0.375     0.285     0.324      1000
#      impressionism      0.276     0.263     0.269      1000
#            baroque      0.374     0.544     0.444      1000
# post_impressionism      0.259     0.267     0.263       984
#
#           accuracy                          0.349      9984
#          macro avg      0.337     0.349     0.338      9984
#       weighted avg      0.337     0.349     0.338      9984

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss', 'learning_rate'])
